# %%
import matplotlib.pyplot as plt

# %%
x = ['03/24/23-M', '03/24/23-A', '03/25/23']
point_point_five_B = [0.134/0.600, 0.137/0.600, 0.155/0.600] 
point_one_B = [0.113/0.553, 0.122/0.553, 0.132/0.553] 
point_two_B = [0.113/0.556, 0.122/0.556, 0.132/0.556] 
point_five_B = [0.114/0.56, 0.122/0.56, 0.136/0.56] 
ej200pvt_B = [0.355/1.047, 0.375/1.047, 0.434/1.047] 

plt.scatter(x, point_point_five_B, label="mhaG116-0.05-1")
plt.scatter(x, point_one_B, label="mhaG116-0.1-1")
plt.scatter(x, point_two_B, label="mhaG116-0.2-1")
plt.scatter(x, point_five_B, label="mhaG116-0.5-1")
plt.scatter(x, ej200pvt_B, label="EJ200PVT-1X1P-A17")
plt.legend(loc=2, prop={'size' : 8})
plt.xlabel('Date of measurement')
plt.ylabel('LY after irrad /LY before irad')
plt.title("Annealing Curve for Mathieu's rods Face B")
plt.show()
