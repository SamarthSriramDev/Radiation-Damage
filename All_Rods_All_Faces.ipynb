# %%
import matplotlib.pyplot as plt

# %%
#x = ['03/24/23-M', '03/24/23-A', '03/25/23', '03/27/23', '03/31/23', '04/07/23', '04/16/23']
x = [0, 7, 30, 81, 177, 345, 561]
point_point_five = [0.130/0.582, 0.136/0.582, 0.151/0.582, 0.178/0.582, 0.211/0.582, 0.254/0.582, 0.319/0.582] 
point_one = [0.114/0.564, 0.123/0.564, 0.136/0.564, 0.155/0.564, 0.185/0.564, 0.241/0.564, 0.278/0.564] 
point_two = [0.123/0.581, 0.129/0.581, 0.137/0.581, 0.156/0.581, 0.187/0.581, 0.229/0.581, 0.276/0.581] 
point_five = [0.113/0.556, 0.118/0.556, 0.134/0.556, 0.149/0.556, 0.176/0.556, 0.210/0.556, 0.246/0.556] 
ej200pvt = [0.352/1.038, 0.376/1.038, 0.437/1.038, 0.469/1.038, 0.584/1.038, 0.728/1.038, 0.759/1.038] 
point_point_five_B = [0.134/0.600, 0.137/0.600, 0.155/0.600, 0.182/0.600, 0.222/0.600, 0.231/0.600, 0.328/0.600] 
point_one_B = [0.113/0.553, 0.122/0.553, 0.132/0.553, 0.150/0.553, 0.163/0.553, 0.231/0.553, 0.267/0.553] 
point_two_B = [0.113/0.556, 0.122/0.556, 0.132/0.556, 0.154/0.556, 0.172/0.556, 0.218/0.556, 0.267/0.556] 
point_five_B = [0.114/0.56, 0.122/0.56, 0.136/0.56, 0.150/0.56, 0.179/0.56, 0.215/0.56, 0.253/0.56] 
ej200pvt_B = [0.355/1.047, 0.375/1.047, 0.434/1.047, 0.488/1.047, 0.592/1.047, 0.693/1.047, 0.76/1.047] 

plt.scatter(x, point_point_five_B, label="mhaG116-0.05-1B")
plt.scatter(x, point_one_B, label="mhaG116-0.1-1B")
plt.scatter(x, point_two_B, label="mhaG116-0.2-1B")
plt.scatter(x, point_five_B, label="mhaG116-0.5-1")
plt.scatter(x, ej200pvt_B, label="EJ200PVT-1X1P-A17B")
plt.scatter(x, point_point_five, label="mhaG116-0.05-1")
plt.scatter(x, point_one, label="mhaG116-0.1-1")
plt.scatter(x, point_two, label="mhaG116-0.2-1")
plt.scatter(x, point_five, label="mhaG116-0.5-1")
plt.scatter(x, ej200pvt, label="EJ200PVT-1X1P-A17")
plt.legend(loc=2, prop={'size' : 6})
plt.xlabel('Hours after irradiation')
plt.ylabel('LY after irrad /LY before irad')
plt.title("Annealing Curve for Mathieu's ")
plt.xlim(0, 600)
plt.show()
